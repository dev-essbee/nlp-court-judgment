# %% [markdown]
# ### Imports

# %%
import pandas as pd
import re
import spacy
from pandarallel import pandarallel
from spacy.matcher import Matcher

pandarallel.initialize(progress_bar=True)
# Out:
# INFO: Pandarallel will run on 8 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
df_all = pd.read_csv(r"../data/cases-tagging-raw.csv")

# %%
df = (
    df_all[df_all["civil"]]
    .drop(["civil", "criminal", "not-defined"], axis=1)
    .reset_index(drop=True)
)

# %%
df = df[df.iloc[:, 1].str.contains("PETITIONER:")].reset_index(drop=True)

# %%
df = df[df.iloc[:, 1].str.contains("CASE NO.:")].reset_index(drop=True)

# %%
nlp = spacy.load("en_core_web_sm")

# %%
matcher = Matcher(nlp.vocab)

# %%
pattern = []
matcher.add("petitioner_pattern", None, pattern)

# %% [markdown]
# ### main-spacy

# %%
def clean_text(row):
    text = row["text"]
    #     text = re.sub(r"\.", "", row["text"])
    return re.sub(r"\s+", " ", text).strip()

# %%
t=df.parallel_apply(clean_text,axis=1)
# Out:
# VBox(children=(HBox(children=(IntProgress(value=0, description='0.00%', max=177), Label(value='0 / 177'))), HB…

# %%
t.iloc[0]
# Out:
# 'http://JUDIS.NIC.IN SUPREME COURT OF INDIA Page 1 of 2 CASE NO.: Appeal (civil) 1815 of 2008 PETITIONER: M/S TEXMACO LTD. CEMENT DIVISION RESPONDENT: A.S. NARASIMHAM DATE OF JUDGMENT: 07/03/2008 BENCH: ALTAMAS KABIR & J.M. PANCHAL JUDGMENT: JUDGMENT O R D E R CIVIL APPEAL NO. 1815 OF 2008 [Arising out of SLP(C)No. 24836 of 2005] Leave granted. We have heard learned counsel for the parties. It appears that the respondent herein was appointed to look after sales promotion work by the appellant herein with effect from 19th May, 1986. His services were thereafter terminated on 21st September, 1993, but on a representation made by him, he was re-appointed by the appellant and was put on probation for six months. Thereafter, on 20th October, 1994 his probation was extended. Subsequently, by letter dated 20th October, 1994, he was informed that his period of probation would be over on 16th November, 1994, and that thereafter, he would be relieved from service after working hours on the same date. Aggrieved by the said communication, the respondent raised a dispute which was referred to the Industrial Tribunal-cum-Labour Court, Anantpur. The said reference was ultimately dismissed by the learned tribunal, which permitted the respondent to file wri t petition before the Andhra Pradesh High Court. The High Court allowed the writ application and set aside the Award passed by the Labour Court with a direction to the appellant to reinstate the respondent in service as a permanent employee of the company, with continuity of service, attendance benefits and full back-wages. Aggrieved by the said order of the learned Single Judge, the appellant moved the Division Bench of the High Court, which passed an interim order on 16th September, 2005 to the following effect:- "Heard both sides. There shall be interim suspension pending appeal subject to compliance of Section 17-B of the I.D. Act from the date of the order." It is the said interim direction of the Division Bench of the High Court whi ch is the subject matter of the present appeal. Mrs. Maheshwari, learned counsel appearing for the appellant submitted that the High Court had erred in directing that the provisions of Section 17-B of the Industrial Disputes Act, 1947 be complied with as a condition for grant of stay. According to her, the Section itself indicates that the benefit of the Section would be available only ag ainst an Award of a Labour Court, Tribunal or National Tribunal which is stayed by a higher court. Mrs. Maheshwari further submitted that in addition to the above, the Division Bench of the High Court had also failed to take into consideration the proviso to Section 17-B which provides that either the High Court or the Supreme Court in passing an order under http://JUDIS.NIC.IN SUPREME COURT OF INDIA Page 2 of 2 Section 17-B would have to be satisfied that the workmen had not been gainfully employed elsewhere and had not been receiving adequate remuneration during the period in question. Mr. R. Santhan Krishnan, learned counsel appearing for the respondent- workman submitted that the provisions of Section 17-B had to be considered in the spirit in which it was enacted and introduced in the Industrial Disputes Act, namely, to provide a means of subsistence to the workmen during the period when the Award made in his favour stood suspended by way of challenge before the higher forum. According to him though the provisions of Section 17-B may not strictly apply in respect of an order of reinstatement passed by the High Court, this Court had in the case of Dena Bank Vs. Kiritkumar T. Patel, 1999(2)SCC-106, held that the powers of the High Court and the Supreme Court under Articles 226 and 136 of the Constitution were not in any way restricted to the provisions of Section 17-B of the Industrial Disputes Act, but that both the High Court and the Supreme Court could give directions which were similar to those contained in Section 17-B to provide interim relief to the workmen duri ...

# %%
doc = nlp(t.iloc[10])

# %%
spacy.displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     http://JUDIS.NIC.IN SUPREME COURT OF INDIA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Page
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  CASE NO.: Appeal (civil)
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5373
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2007
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  PETITIONER:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Delhi Development Authority
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  RESPONDENT:
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Arjun Lal Satija
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and Ors DATE OF JUDGMENT:
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     23/11/2007
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  BENCH: Dr.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ARIJIT PASAYAT &amp; LOKESHWAR SINGH PANTA &amp; P. SATHASIVAM
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  JUDGMENT: J
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U D G
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  M E N T CIVIL APPEAL NO. 5373 OF
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2007
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  (Arising out of S.L.P. (C) No.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     4024
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of 2006) Dr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ARIJIT PASAYAT
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     J. 1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . Leave granted.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# . Challenge in this appeal is to by a Division Bench of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Delhi High Court
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  allowing the writ petition filed by the respondent
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     no.1 3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . Factual background in a nutshell is as follows: The land to which the present dispute relates was allotted to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Mianwali District Cooperative House Building Society Ltd.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Flat No
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# . 3-A,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     New Qutab Road
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Delhi
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . Father of Respondent No.1 was a member of the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Society
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# <

# %%
for token in doc:
    print(token.text, token.pos_, token.dep_, token.head.text, token.tag_)
# Out:
# http://JUDIS.NIC.IN PUNCT compound COURT ``
# SUPREME ADJ compound COURT JJ
# COURT PROPN ROOT COURT NNP
# OF ADP prep COURT IN
# INDIA PROPN pobj OF NNP
# Page PROPN ROOT Page NNP
# 1 NUM nummod Page CD
# of ADP prep Page IN
# 4 NUM nummod CASE CD
# CASE NOUN pobj of NN
# NO INTJ nummod Page UH
# . PUNCT punct Page .
# : PUNCT punct PETITIONER :
# Appeal NOUN nsubj PETITIONER NN
# ( PUNCT punct civil -LRB-
# civil ADJ appos Appeal JJ
# ) PUNCT punct civil -RRB-
# 5373 NUM appos Appeal CD
# of ADP prep 5373 IN
# 2007 NUM pobj of CD
# PETITIONER PROPN ROOT PETITIONER NNP
# : PUNCT punct PETITIONER :
# Delhi PROPN compound Authority NNP
# Development PROPN compound Authority NNP
# Authority PROPN compound RESPONDENT NNP
# RESPONDENT NOUN ROOT RESPONDENT NN
# : PUNCT punct RESPONDENT :
# Arjun PROPN compound Satija NNP
# Lal PROPN compound Satija NNP
# Satija PROPN ROOT Satija NNP
# and CCONJ cc Satija CC
# Ors PROPN compound DATE NNP
# DATE PROPN conj Satija NNP
# OF ADP prep DATE IN
# JUDGMENT PROPN pobj OF NNP
# : PUNCT punct Satija :
# 23/11/2007 NUM appos Satija CD
# BENCH PROPN ROOT BENCH NNP
# : PUNCT punct BENCH :
# Dr. PROPN compound PASAYAT NNP
# ARIJIT PROPN compound PASAYAT NNP
# PASAYAT PROPN ROOT PASAYAT NNP
# & CCONJ cc PASAYAT CC
# LOKESHWAR PROPN compound PANTA NNP
# SINGH PROPN compound PANTA NNP
# PANTA PROPN conj PASAYAT NNP
# & CCONJ cc PANTA CC
# P. PROPN compound JUDGMENT NNP
# SATHASIVAM PROPN compound JUDGMENT NNP
# JUDGMENT PROPN appos PASAYAT NNP
# : PUNCT punct PASAYAT :
# J PROPN ROOT J NNP
# U PROPN compound G NNP
# D PROPN compound G NNP
# G NOUN appos J NN
# M PROPN compound E NNP
# E NOUN ROOT E NN
# N PROPN compound T NNP
# T PROPN compound APPEAL NNP
# CIVIL PROPN compound APPEAL NNP
# APPEAL PROPN ROOT APPEAL NNP
# NO NOUN ROOT NO NN
# . NOUN punct NO NN
# 5373 NUM ROOT 5373 CD
# OF ADP prep 5373 IN
# 2007 NUM pobj OF CD
# ( PUNCT ROOT ( -LRB-
# Arising VERB intj ( VBG
# out SCONJ prep Arising IN
# of ADP prep out IN
# S.L.P. NOUN pobj of NN
# ( PUNCT punct C -LRB-
# C PROPN appos S.L.P. NNP
# ) PUNCT punct C -RRB-
# No NOUN dep . NN
# . NOUN ROOT . NN
# 4024 NUM nummod . CD
# of ADP prep 4024 IN
# 2006 NUM pobj of CD
# ) PUNCT punct . -RRB-
# Dr. PROPN compound PASAYAT NNP
# ARIJIT PROPN compound PASAYAT NNP
# PASAYAT PROPN ROOT PASAYAT NNP
# , PUNCT punct PASAYAT ,
# J. PROPN npadvmod PASAYAT NNP
# 1 NUM nummod J. CD
# . PUNCT punct PASAYAT .
# Leave VERB nsubj granted VB
# granted VERB ROOT granted VBN
# . PUNCT punct granted .
# 2 X ROOT 2 LS
# . PUNCT punct 2 .
# Challenge NOUN nsubj is NN
# in ADP prep Challenge IN
# this DET det appeal DT
# appeal NOUN pobj in NN
# is AUX ROOT is VBZ
# to ADP prep is IN
# by ADP prep is IN
# a DET det Bench DT
# Division PROPN compound Bench NNP
# Bench PROPN pobj by NNP
# of ADP prep Bench IN
# the DET det Court DT
# Delhi PROPN compound Court NNP
# High PROPN compound Court NNP
# Court PROPN pobj of NNP
# allowing VERB xcomp is VBG
# the DET det petition DT
# writ NOUN compound petition NN
# petition NOUN dobj allowing NN
# filed VERB acl petition VBN
# by ADP agent filed IN
# the DET det no.1 DT
# respondent NOUN compound no.1 NN
# no.1 PROPN pobj by NNP
# 3 NUM nummod no.1 CD
# . PUNCT punct is .
# Factual ADJ amod background JJ
# background NOUN nsubj is NN
# in ADP prep background IN
# a DET det nutshell DT
# nutshell NOUN pobj in NN
# is AUX ccomp allotted VBZ
# as SCONJ mark follows IN
# follows VERB advcl is VBZ
# : PUNCT punct allotted :
# The DET det land DT
# land NOUN nsubjpass allotted NN
# to PART prep relates TO
# which DET pobj to WDT
# the DET det dispute DT
# present ADJ amod dispute JJ
# dispute NOUN nsubj relates NN
# relates VERB relcl land VBZ
# was AUX auxpass allotted VBD
# allotted VERB ROOT allotted VBN
# to ADP prep allotted IN
# The DET det Ltd. DT
# Mianwali PROPN compound Ltd. NNP
# District PROPN compound House NNP
# Cooperative PROPN compound House NNP
# House PROPN compound Ltd. NNP
# Building PROPN compound Ltd. NNP
# Society PROPN compound Ltd. NNP
# Ltd. PROPN pobj to NNP
# , PUNCT punct Ltd. ,
# Flat PROPN compound . NNP
# No NOUN dep . NN
# . NOUN appos Ltd. NN
# 3-A NUM npadvmod Road CD
# , PUNCT punct Road ,
# New PROPN compound Road NNP
# Qutab PROPN compound Road NNP
# Road PROPN ROOT Road NNP
# , PUNCT punct Road ,
# Delhi PROPN appos Road NNP
# . PUNCT punct Road .
# Father PROPN nsubj was NNP
# of ADP prep Father IN
# Respondent PROPN compound No.1 NNP
# No.1 NOUN pobj of NN
# was AUX ROOT was VBD
# a DET det member DT
# member NOUN attr was NN
# of ADP prep member IN
# the DET det Society DT
# Society PROPN pobj of NNP
# . PUNCT punct was .
# Members NOUN nsubjpass entitled NNS
# of ADP prep Members IN
# the DET det Society DT
# Society PROPN pobj of NNP
# were AUX auxpass entitled VBD
# entitled VERB ROOT entitled VBN
# to PART aux included TO
# be AUX auxpass included VB
# included VERB xcomp entitled VBN
# in ADP prep included IN
# the DET det draw DT
# draw NOUN pobj in NN
# of ADP prep draw IN
# lots NOUN pobj of NNS
# for ADP prep draw IN
# allotment NOUN pobj for NN
# of ADP prep allotment IN
# land NOUN pobj of NN
# . PUNCT punct entitled .
# Before ADP mark done IN
# any DET det allotment DT
# allotment NOUN nsubjpass done NN
# of ADP prep allotment IN
# land NOUN pobj of NN
# was AUX auxpass done VBD
# done VERB advcl died VBN
# , PUNCT punct died ,
# father NOUN nsubj died NN
# of ADP prep father IN
# respondent PROPN pobj of NNP
# No.1 PROPN appos father NNP
# died VERB ROOT died VBD
# on ADP prep died IN
# 22.11.1974 PROPN pobj on NNP
# . PUNCT punct died .
# Respondent NOUN compound No.1 NN
# No.1 NOUN nsubj filed NN
# filed VERB ROOT filed VBD
# an DET det application DT
# application NOUN dobj filed NN
# for ADP prep application IN
# issuance NOUN pobj for NN
# of ADP prep issuance IN
# succession NOUN compound certificate NN
# certificate NOUN pobj of NN
# which DET nsubjpass allowed WDT
# was AUX auxpass allowed VBD
# allowed VERB relcl issuance VBN
# on ADP prep allowed IN
# 17.02.1986 PROPN pobj on NNP
# . PUNCT punct filed .
# The DET det Committee DT
# Managing PROPN compound Committee NNP
# Committee PROPN nsubj adopted NNP
# of ADP prep Committee IN
# respondent PROPN pobj of NNP
# No.3-Society PROPN appos Committee NNP
# adopted VERB ROOT adopted VBD
# a DET det resolution DT
# resolution NOUN dobj adopted NN
# transferring VERB acl resolution VBG
# the DET det membership DT
# membership NOUN dobj transferring NN
# of ADP prep membership IN
# Shri PROPN compound Satija NNP
# K.K. PROPN compound Satija NNP
# Satija PROPN pobj of NNP
# in ADP prep transferring IN
# favour NOUN pobj in NN
# of ADP prep favour IN
# respondent NOUN compound No.1 NN
# No.1 NOUN pobj of NN
# . PUNCT punct adopted .
# Thereafter ADV advmod approached RB
# , PUNCT punct approached ,
# respondent NOUN compound No.1 NN
# No.1 NOUN nsubj approached NN
# approached VERB ROOT approached VBD
# the DET det office DT
# office NOUN dobj approached NN
# of ADP prep office IN
# the DET det Registrar DT
# Registrar PROPN pobj of NNP
# of ADP prep Registrar IN
# Cooperative PROPN compound Societies NNP
# Societies PROPN pobj of NNP
# ( PUNCT punct Registrar -LRB-
# in ADP prep Registrar IN
# short ADJ amod in JJ
# ’ PUNCT punct Registrar ''
# the DET det Registrar DT
# Registrar PROPN dep approached NNP
# ’ PUNCT punct Registrar ''
# ) PUNCT punct Registrar -RRB-
# for ADP prep approached IN
# clearance NOUN pobj for NN
# and CCONJ cc for CC
# for ADP conj for IN
# forwarding VERB pcomp for VBG
# his DET poss name PRP$
# name NOUN dobj forwarding NN
# for ADP prep forwarding IN
# inclusion NOUN pobj for NN
# in ADP prep inclusion IN
# the DET det draw DT
# draw NOUN pobj in NN
# of ADP prep draw IN
# lots NOUN pobj of NNS
# by ADP prep forwarding IN
# the DET det appellant DT
# appellant NOUN pobj by NN
# . PUNCT punct approached .
# On ADP prep issued IN
# 16.05.1994 NUM pobj On CD
# , PUNCT punct issued ,
# the DET det Registrar DT
# Registrar PROPN nsubj issued NNP
# issued VERB ROOT issued VBD
# a DET det show DT
# show NOUN dobj issued NN
# cause NOUN compound notice NN
# notice NOUN dobj issued NN
# to PART aux respondent TO
# respondent VERB acl notice VB
# No.1 NOUN dobj respondent NN
# as SCONJ prep respondent IN
# to ADP prep as IN
# why ADV advmod cancelled WRB
# his DET poss membership PRP$
# membership NOUN nsubjpass cancelled NN
# of ADP prep membership IN
# the DET det Society DT
# Society PROPN pobj of NNP
# be AUX auxpass cancelled VB
# not PART neg cancelled RB
# cancelled VERB pcomp to VBN
# for ADP prep cancelled IN
# the DET det reason DT
# reason NOUN pobj for NN
# that ADV mark owning WRB
# he PRON nsubj owning PRP
# was AUX aux owning VBD
# already ADV advmod owning RB
# owning VERB acl reason VBG
# a DET det house DT
# residential ADJ amod house JJ
# house NOUN dobj owning NN
# at ADP prep owning IN
# A-120 ADJ dep , JJ
# , PUNCT punct at ,
# Saraswati PROPN compound Vihar NNP
# Vihar PROPN pobj at NNP
# , PUNCT punct Vihar ,
# Delhi PROPN appos Vihar NNP
# . PUNCT punct issued .
# On ADP prep passed IN
# 13.10.1994 PROPN pobj On NNP
# , PUNCT punct passed ,
# an DET det order DT
# order NOUN nsubjpass passed NN
# in ADP prep order IN
# this DET det regard DT
# regard NOUN pobj in NN
# was AUX auxpass passed VBD
# passed VERB ROOT passed VBN
# by ADP agent passed IN
# the DET det Registrar DT
# Registrar PROPN pobj by NNP
# . PUNCT punct passed .
# But CCONJ cc restored CC
# the DET det membership DT
# membership NOUN nsubjpass restored NN
# was AUX auxpass restored VBD
# restored VERB ROOT restored VBN
# by ADP agent restored IN
# the DET det Government DT
# Government PROPN pobj by NNP
# in ADP prep restored IN
# a DET det petition DT
# revision NOUN compound petition NN
# petition NOUN pobj in NN
# filed VERB acl petition VBN
# under ADP prep filed IN
# Section PROPN pobj under NNP
# 80 NUM nummod Section CD
# of ADP prep Section IN
# the DET det Act DT
# Delhi PROPN compound Societies NNP
# Cooperative PROPN compound Societies NNP
# Societies PROPN compound Act NNPS
# Act PROPN pobj of NNP
# , PUNCT punct Act ,
# 1972 NUM appos Act CD
# ( PUNCT punct Act -LRB-
# in ADP prep Act IN
# short ADJ amod in JJ
# ’ PUNCT punct Act ''
# the DET det Act DT
# Act PROPN appos membership NNP
# ’ PUNCT punct Act ''
# ) PUNCT punct Act -RRB-
# . PUNCT punct restored .
# A DET det petition DT
# writ NOUN amod petition NN
# petition NOUN nsubjpass filed NN
# was AUX auxpass filed VBD
# filed VERB ROOT filed VBN
# before ADP prep filed IN
# the DET det Court DT
# Delhi PROPN compound Court NNP
# High PROPN compound Court NNP
# Court PROPN nsubj challenging NNP
# challenging VERB pcomp before VBG
# the DET det inclusion DT
# non ADJ dep - JJ
# - ADJ dep inclusion JJ
# inclusion NOUN dobj challenging NN
# of ADP prep inclusion IN
# the DET det No.1 DT
# respondent NOUN compound No.1 NN
# No.1 NOUN pobj of NN
# ’s PART punct inclusion POS
# name NOUN appos inclusion NN
# for ADP prep name IN
# allotment NOUN pobj for NN
# . PUNCT punct filed .
# The DET det Court DT
# Delhi PROPN compound Court NNP
# High PROPN compound Court NNP
# Court PROPN nsubj passed NNP
# passed VERB ROOT passed VBD
# an DET det order DT
# order NOUN dobj passed NN
# directing VERB acl order VBG
# clearance NOUN dobj directing NN
# of ADP prep clearance IN
# the DET det name DT
# name NOUN pobj of NN
# of ADP prep name IN
# respondent NOUN compound No.1 NN
# No.1 PROPN pobj of NNP
# , PUNCT punct passed ,
# since SCONJ mark passed IN
# no DET det order DT
# order NOUN nsubjpass passed NN
# was AUX auxpass passed VBD
# passed VERB advcl passed VBN
# in ADP prep passed IN
# terms NOUN pobj in NNS
# of ADP prep terms IN
# the DET det Court DT
# High PROPN compound Court NNP
# Court PROPN pobj of NNP
# ’s NOUN punct passed NN
# order NOUN npadvmod passed NN
# . PUNCT punct passed .
# Two NUM nummod weeks CD
# and CCONJ cc Two CC
# four NUM conj Two CD
# weeks NOUN poss time NNS
# ’ PUNCT punct weeks ''
# time NOUN nsubjpass granted NN
# were AUX auxpass granted VBD
# granted VERB ROOT granted VBN
# for ADP prep granted IN
# inclusion NOUN pobj for NN
# of ADP prep inclusion IN
# name NOUN pobj of NN
# and CCONJ cc name CC
# allotment NOUN conj name NN
# of ADP prep name IN
# the DET det plot DT
# plot NOUN pobj of NN
# . PUNCT punct granted .
# Since SCONJ prep done IN
# same ADJ amod Since JJ
# was AUX auxpass done VBD
# not PART neg done RB
# done VERB ROOT done VBN
# contempt NOUN compound proceedings NN
# proceedings NOUN nsubjpass initiated NNS
# were AUX auxpass initiated VBD
# initiated VERB conj done VBN
# . PUNCT punct initiated .
# In ADP prep was IN
# these DET det proceedings DT
# proceedings NOUN pobj In NNS
# , PUNCT punct was ,
# the DET det appellant DT
# present ADJ amod appellant JJ
# appellant NOUN nsubj was NN
# was AUX ROOT was VBD
# not PART neg was RB
# a DET det party DT
# party NOUN attr was NN
# . PUNCT punct was .
# In ADP prep made IN
# the DET det proceedings DT
# contempt NOUN compound proceedings NN
# proceedings NOUN pobj In NNS
# , PUNCT punct made ,
# a DET det statement DT
# statement NOUN nsubjpass made NN
# was AUX auxpass made VBD
# made VERB ROOT made VBN
# by ADP agent made IN
# the DET det COURT DT
# http://JUDIS.NIC.IN PROPN compound COURT NNP
# SUPREME PROPN compound COURT NNP
# COURT PROPN pobj by NNP
# OF ADP prep COURT IN
# INDIA PROPN intj OF NNP
# Page PROPN ROOT Page NNP
# 2 NUM nummod Page CD
# of ADP prep Page IN
# 4 NUM nummod official CD
# official NOUN pobj of NN
# of ADP prep official IN
# the DET det Registrar DT
# Registrar PROPN pobj of NNP
# , PUNCT punct official ,
# Cooperative PROPN compound respondent NNP
# Societies PROPN compound respondent NNP
# - PUNCT punct respondent HYPH
# respondent NOUN compound No.2 NN
# No.2 NOUN appos official NN
# that DET dobj letter WDT
# the DET det letter DT
# clearance NOUN compound letter NN
# letter NOUN relcl No.2 NN
# for ADP prep letter IN
# holding VERB pcomp for VBG
# draw NOUN dobj holding NN
# of ADP prep draw IN
# lots NOUN pobj of NNS
# for ADP prep holding IN
# allotment NOUN pobj for NN
# of ADP prep allotment IN
# plot NOUN pobj of NN
# of ADP prep plot IN
# 300 NUM nummod . CD
# sq PROPN dep . NNP
# . PROPN punct Page NNP
# yds PROPN ROOT yds NNP
# . PUNCT punct yds .
# would VERB aux issued MD
# be AUX auxpass issued VB
# issued VERB ROOT issued VBN
# immediately ADV advmod issued RB
# . PUNCT punct issued .
# Accordingly ADV advmod disposed RB
# , PUNCT punct disposed ,
# the DET det application DT
# application NOUN nsubjpass disposed NN
# was AUX auxpass disposed VBD
# disposed VERB ROOT disposed VBN
# of ADP prep disposed IN
# . PUNCT punct disposed .
# On ADP prep approached IN
# 19.02.2004 PROPN pobj On NNP
# , PUNCT punct approached ,
# respondent NOUN compound No.1 NN
# No.1 NOUN nsubj approached NN
# approached VERB ROOT approached VBD
# the DET det appellant DT
# appellant NOUN dobj approached NN
# for ADP prep appellant IN
# allotment NOUN pobj for NN
# in ADP prep approached IN
# the DET det draw DT
# draw NOUN pobj in NN
# of ADP prep draw IN
# lots NOUN pobj of NNS
# . PUNCT punct approached .
# At ADP prep came IN
# that DET det point DT
# point NOUN pobj At NN
# of ADP prep point IN
# time NOUN pobj of NN
# , PUNCT punct came ,
# the DET det appellant DT
# appellant NOUN nsubj came NN
# came VERB ROOT came VBD
# to PART aux know TO
# know VERB advcl came VB
# that SCONJ det order IN
# order NOUN nsubjpass passed NN
# relating VERB acl order VBG
# to ADP prep relating IN
# inclusion NOUN pobj to NN
# of ADP prep inclusion IN
# the DET det name DT
# name NOUN pobj of NN
# of ADP prep name IN
# respondent NOUN compound No.1 NN
# No.1 PROPN pobj of NNP
# had AUX aux passed VBD
# been AUX auxpass passed VBN
# passed VERB ccomp know VBN
# . PUNCT punct came .
# Respondent VERB compound No.1 VB
# No.1 NOUN nsubj filed NN
# filed VERB ROOT filed VBD
# another DET det petition DT
# writ NOUN amod petition NN
# petition NOUN dobj filed NN
# seeking VERB acl petition VBG
# a DET det writ DT
# writ NOUN dobj seeking NN
# of ADP prep writ IN
# mandamus NOUN pobj of NN
# against ADP prep writ IN
# the DET det appellant DT
# appellant NOUN pobj against NN
# to ADP prep appellant IN
# allot VERB pobj to VB
# and CCONJ cc writ CC
# handover VERB conj writ VB
# the DET det plot DT
# plot NOUN dobj handover NN
# . PUNCT punct filed .
# The DET det Bench DT
# Division PROPN compound Bench NNP
# Bench PROPN nsubj allowed NNP
# allowed VERB ROOT allowed VBD
# the DET det petition DT
# petition NOUN dobj allowed NN
# and CCONJ cc allowed CC
# held VERB conj allowed VBD
# that SCONJ mark was IN
# there PRON expl was EX
# was AUX ccomp held VBD
# no DET det substance DT
# substance NOUN attr was NN
# in ADP prep substance IN
# the DET det plea DT
# plea NOUN pobj in NN
# raised VERB acl plea VBN
# by ADP agent raised IN
# the DET det appellant DT
# appellant NOUN pobj by NN
# and CCONJ cc was CC
# that SCONJ mark are IN
# the DET det membership DT
# membership NOUN nsubj are NN
# of ADP prep membership IN
# a DET det society DT
# society NOUN pobj of NN
# and CCONJ cc society CC
# eligibility NOUN conj society NN
# for ADP prep membership IN
# a DET det plot DT
# plot NOUN pobj for NN
# are AUX conj was VBP
# entirely ADV advmod independent RB
# independent ADJ amod issues JJ
# issues NOUN attr are NNS
# . PUNCT punct allowed .
# It PRON nsubj find PRP
# also ADV advmod find RB
# did AUX aux find VBD
# not PART neg find RB
# find VERB ROOT find VB
# any DET det substance DT
# substance NOUN dobj find NN
# in ADP prep substance IN
# the DET det plea DT
# plea NOUN pobj in NN
# that DET mark was WDT
# because SCONJ mark having IN
# respondent NOUN compound No.1 NN
# No.1 PROPN nsubj having NNP
# was AUX aux having VBD
# having VERB advcl was VBG
# another DET det plot DT
# plot NOUN dobj having NN
# in ADP prep plot IN
# his DET poss name PRP$
# name NOUN pobj in NN
# , PUNCT punct was ,
# he PRON nsubj was PRP
# was AUX relcl substance VBD
# ineligible ADJ acomp was JJ
# for ADP prep ineligible IN
# allotment NOUN pobj for NN
# of ADP prep allotment IN
# a DET det plot DT
# plot NOUN pobj of NN
# in ADP prep plot IN
# the DET det society DT
# society NOUN pobj in NN
# . PUNCT punct find .
# The DET det appellant DT
# appellant NOUN nsubj centred NN
# ’s PART punct appellant POS
# contention NOUN appos appellant NN
# centred VERB ROOT centred VBD
# around ADP prep centred IN
# Rule-17 PROPN pobj around NNP
# of ADP prep Rule-17 IN
# the DET det Authority DT
# Delhi PROPN compound Authority NNP
# Development PROPN compound Authority NNP
# Authority PROPN pobj of NNP
# ( PUNCT punct Disposal -LRB-
# Disposal PROPN ROOT Disposal NNP
# of ADP prep Disposal IN
# Developed VERB amod Land VBN
# Nazul PROPN compound Land NNP
# Land PROPN pobj of NNP
# ) PUNCT punct Disposal -RRB-
# Rules NOUN ROOT Rules NNS
# , PUNCT punct Rules ,
# 1981 NUM appos Rules CD
# ( PUNCT punct Rules -LRB-
# in ADP prep Rules IN
# short ADJ amod in JJ
# the DET det Rules DT
# ’ PUNCT punct Rules ``
# Rules NOUN pobj in NNS
# ’ PUNCT punct in ''
# ) PUNCT punct Rules -RRB-
# . PUNCT punct Rules .
# 4 X ROOT 4 LS
# . PUNCT punct 4 .
# The DET det Court DT
# High PROPN compound Court NNP
# Court PROPN nsubj held NNP
# held VERB ROOT held VBD
# that SCONJ mark are IN
# Rules NOUN nsubj are NNS
# are AUX ccomp held VBP
# not PART neg are RB
# applicable ADJ acomp are JJ
# to ADP prep applicable IN
# the DET det case DT
# case NOUN pobj to NN
# of ADP prep case IN
# respondent PROPN pobj of NNP
# No.1 PROPN dep . NNP
# . PUNCT punct held .
# 5 X nummod . LS
# . PUNCT punct held .
# In ADP prep submitted IN
# support NOUN pobj In NN
# of ADP prep support IN
# the DET det appeal DT
# appeal NOUN pobj of NN
# , PUNCT punct learned ,
# learned VERB amod counsel VBD
# counsel NOUN nsubj submitted NN
# for ADP prep counsel IN
# the DET det appellant DT
# appellant NOUN pobj for NN
# submitted VERB ROOT submitted VBD
# that SCONJ mark lost IN
# true ADJ amod import JJ
# import NOUN nsubjpass lost NN
# of ADP prep import IN
# Rule PROPN pobj of NNP
# 17 NUM nummod Rule CD
# has AUX aux lost VBZ
# been AUX auxpass lost VBN
# lost VERB ccomp submitted VBN
# sight NOUN dobj lost NN
# of ADP prep sight IN
# by ADP agent lost IN
# the DET det Court DT
# High PROPN compound Court NNP
# Court PROPN pobj by NNP
# . PUNCT punct submitted .
# On ADP prep learned IN
# the DET det hand DT
# other ADJ amod hand JJ
# hand NOUN pobj On NN
# , PUNCT punct learned ,
# learned VERB amod counsel VBD
# counsel NOUN ROOT counsel NN
# for ADP prep counsel IN
# the DET det respondent DT
# respondent NOUN pobj for NN
# submitted VERB acl respondent VBD
# that SCONJ mark has IN
# Rule PROPN nsubj has NNP
# 17 NUM nummod Rule CD
# has AUX ccomp submitted VBZ
# no DET det application DT
# application NOUN dobj has NN
# as SCONJ prep application IN
# the DET det land DT
# land NOUN nsubj was NN
# in ADP prep land IN
# question NOUN pobj in NN
# was AUX acl application VBD
# not PART neg was RB
# Nazul PROPN compound land NNP
# land NOUN attr was NN
# . PUNCT punct counsel .
# It PRON nsubjpass submitted PRP
# was AUX auxpass submitted VBD
# also ADV advmod submitted RB
# submitted VERB ROOT submitted VBN
# that SCONJ mark apply IN
# Section NOUN nsubj apply NN
# 87 NUM nummod Section CD
# of ADP prep Section IN
# the DET det Act DT
# Act PROPN pobj of NNP
# on ADP prep placed IN
# which DET pobj on WDT
# the DET det appellant DT
# appellant NOUN nsubj placed NN
# has AUX aux placed VBZ
# placed VERB relcl Act VBN
# reliance NOUN dobj placed NN
# , PUNCT punct apply ,
# does AUX aux apply VBZ
# not PART neg apply RB
# apply VERB ccomp submitted VB
# to ADP prep apply IN
# the DET det case DT
# present ADJ amod case JJ
# case NOUN pobj to NN
# . PUNCT punct submitted .
# 6 NUM ROOT 6 CD
# . PUNCT punct 6 .
# The DET det dispute DT
# dispute NOUN nsubj revolves NN
# revolves VERB ROOT revolves VBZ
# primarily ADV advmod around RB
# around ADP prep revolves IN
# applicability NOUN pobj around NN
# of ADP prep applicability IN
# Rule-17 PROPN pobj of NNP
# . PUNCT punct revolves .
# The DET det reads DT
# same ADJ amod reads JJ
# reads VERB ROOT reads VBZ
# as SCONJ mark follows IN
# follows VERB advcl reads VBZ
# : PUNCT punct follows :
# " PUNCT punct follows ``
# 17 NUM ROOT 17 CD
# . PUNCT punct 17 .
# General ADJ amod restriction JJ
# restriction NOUN ROOT restriction NN
# to PART aux allotment TO
# allotment NOUN relcl restriction NN
# for ADP prep allotment IN
# residential ADJ amod purposes JJ
# purposes NOUN pobj for NNS
# . PUNCT punct restriction .
# Notwithstanding ADP prep allotted IN
# anything PRON pobj Notwithstanding NN
# contained VERB acl anything VBN
# in ADP prep contained IN
# these DET det rules DT
# rules NOUN pobj in NNS
# , PUNCT punct allotted ,
# no DET det plot DT
# plot NOUN nsubjpass allotted NN
# of ADP prep plot IN
# Nazul PROPN compound land NNP
# land NOUN pobj of NN
# shall VERB aux allotted MD
# be AUX auxpass allotted VB
# allotted VERB ROOT allotted VBN
# for ADP prep allotted IN
# residential ADJ amod purposes JJ
# purposes NOUN pobj for NNS
# , PUNCT punct allotted ,
# to ADP prep allotted IN
# an DET det other DT
# individual NOUN amod other NN
# other ADJ pobj to JJ
# than SCONJ prep other IN
# an DET det individual DT
# individual NOUN pobj than NN
# referred VERB acl individual VBN
# to ADP prep referred IN
# in ADP prep referred IN
# clause NOUN pobj in NN
# ( PUNCT punct clause -LRB-
# i NOUN appos clause NN
# ) PUNCT punct clause -RRB-
# of ADP prep clause IN
# rule NOUN pobj of NN
# 6 NUM nummod rule CD
# , PUNCT punct rule ,
# who PRON conj rule WP
# or CCONJ cc who CC
# whose DET poss wife WP$
# wife NOUN compound husband NN
# husband NOUN conj who NN
# or CCONJ cc husband CC
# any DET conj husband DT
# of ADP prep any IN
# his DET poss children PRP$
# or CCONJ cc children CC
# her DET poss children PRP$
# dependent ADJ amod children JJ
# children NOUN pobj of NNS
# whether SCONJ mark minor IN
# minor ADJ advcl allotted JJ
# or CCONJ cc minor CC
# not PART conj minor RB
# , PUNCT punct allotted ,
# or CCONJ cc allotted CC
# any DET conj allotted DT
# of ADP prep any IN
# his DET poss parents PRP$
# her DET poss parents PRP$
# dependent ADJ amod parents JJ
# parents NOUN pobj of NNS
# or CCONJ cc any CC
# dependent ADJ amod brothers JJ
# minor ADJ amod brothers JJ
# brothers NOUN conj any NNS
# , PUNCT punct brothers ,
# or CCONJ cc brothers CC
# sisters NOUN conj brothers NNS
# , PUNCT punct any ,
# ordinarily ADV advmod residing RB
# residing VERB acl any VBG
# with ADP prep residing IN
# such ADJ amod individual JJ
# individual ADJ pobj with JJ
# , PUNCT punct residing ,
# own ADJ conj residing JJ
# in ADP prep own IN
# full ADJ amod in JJ
# or CCONJ cc full CC
# in ADP conj full IN
# part NOUN pobj in NN
# , PUNCT punct own ,
# on ADP prep own IN
# lease NOUN compound hold NN
# hold NOUN pobj on NN
# or CCONJ cc hold CC
# free ADJ amod hold JJ
# hold NOUN compound basis NN
# basis NOUN conj hold NN
# , PUNCT punct own ,
# any DET det land DT
# residential ADJ amod land JJ
# land NOUN conj own NN
# or CCONJ cc land CC
# house NOUN conj land NN
# or CCONJ cc own CC
# who PRON nsubjpass allotted WP
# has AUX aux allotted VBZ
# been AUX auxpass allotted VBN
# allotted VERB conj own VBN
# on ADP prep allotted IN
# hire NOUN compound purchase NN
# purchase NOUN compound basis NN
# basis NOUN pobj on NN
# by ADP prep basis IN
# residential ADJ amod land JJ
# land NOUN pobj by NN
# or CCONJ cc land CC
# house NOUN conj land NN
# in ADP prep land IN
# the DET det Territory DT
# Union PROPN compound Territory NNP
# Territory PROPN pobj in NNP
# of ADP prep Territory IN
# Delhi PROPN pobj of NNP
# ; PUNCT punct any :
# Provided VERB conj allotted VBN
# that SCONJ mark is IN
# where ADV advmod is WRB
# , PUNCT punct is ,
# on ADP prep is IN
# the DET det date DT
# date NOUN pobj on NN
# of ADP prep date IN
# allotment NOUN pobj of NN
# of ADP prep allotment IN
# Nazul PROPN compound land NNP
# land NOUN pobj of NN
# , PUNCT punct land ,
# ( PUNCT punct a -LRB-
# a X meta land LS
# ) PUNCT punct a -RRB-
# the DET det land DT
# other ADJ amod land JJ
# land NOUN nsubj is NN
# owned VERB acl land VBN
# by ADP agent owned IN
# or CCONJ cc owned CC
# allotted VERB conj owned VBN
# to ADP prep allotted IN
# such ADJ amod individual JJ
# individual NOUN pobj to NN
# is AUX ccomp Provided VBZ
# less ADJ amod 67 JJR
# than SCONJ quantmod 67 IN
# 67 NUM nummod metres CD
# square ADJ amod metres JJ
# metres NOUN attr is NNS
# , PUNCT punct is ,
# or CCONJ cc is CC
# ( PUNCT punct b -LRB-
# b X meta is LS
# ) PUNCT punct b -RRB-
# the DET det house DT
# house NOUN nsubj is NN
# owned VERB acl house VBN
# by ADP agent owned IN
# such ADJ amod individual JJ
# individual NOUN pobj by NN
# is AUX conj is VBZ
# a DET det plot DT
# plot NOUN attr is NN
# of ADP prep plot IN
# land NOUN pobj of NN
# which DET nsubj measures WDT
# measures VERB relcl land VBZ
# less ADJ amod 67 JJR
# than SCONJ quantmod 67 IN
# 67 NUM nummod metres CD
# square ADJ amod metres JJ
# metres NOUN dobj measures NNS
# , PUNCT punct plot ,
# or CCONJ cc plot CC
# ( PUNCT punct c -LRB-
# c NOUN meta share NN
# ) PUNCT punct c -RRB-
# the DET det share DT
# share NOUN conj plot NN
# of ADP prep share IN
# such ADJ amod individual JJ
# individual NOUN pobj of NN
# in ADP prep share IN
# any DET det measures DT
# such ADJ amod measures JJ
# other ADJ amod measures JJ
# land NOUN nmod measures NN
# or CCONJ cc land CC
# house NOUN conj land NN
# measures NOUN pobj in NNS
# less ADJ amod 67 JJR
# than SCONJ quantmod 67 IN
# 67 NUM nummod metres CD
# square ADJ amod metres JJ
# metres NOUN appos share NNS
# , PUNCT punct allotted ,
# he PRON nsubjpass allotted PRP
# may VERB aux allotted MD
# be AUX auxpass allotted VB
# allotted VERB conj allotted VBN
# a DET det plot DT
# plot NOUN dobj allotted NN
# of ADP prep plot IN
# http://JUDIS.NIC.IN ADJ compound COURT JJ
# SUPREME PROPN compound COURT NNP
# COURT PROPN nmod Page NNP
# OF ADP prep COURT IN
# INDIA PROPN pobj OF NNP
# Page PROPN pobj of NNP
# 3 NUM nummod Page CD
# of ADP quantmod 4 IN
# 4 NUM nummod land CD
# Nazul PROPN compound land NNP
# land NOUN appos Page NN
# in ADP prep Page IN
# accordance NOUN pobj in NN
# with ADP prep accordance IN
# the DET det provision DT
# other ADJ amod provision JJ
# provision NOUN pobj with NN
# of ADP prep provision IN
# these DET det rules DT
# rules NOUN pobj of NNS
# . PUNCT punct allotted .
# " PUNCT ROOT " ''
# 7 NUM ROOT 7 CD
# . PUNCT punct 7 .
# A DET det reading DT
# bare ADJ amod reading JJ
# reading NOUN nsubj makes NN
# of ADP prep reading IN
# the DET det Rule DT
# Rule PROPN pobj of NNP
# makes VERB ROOT makes VBZ
# it PRON nsubj clear PRP
# clear ADJ ccomp makes JJ
# that SCONJ mark applies IN
# it PRON nsubj applies PRP
# applies VERB advcl clear VBZ
# only ADV advmod to RB
# to ADP prep applies IN
# Nazul PROPN compound land NNP
# land NOUN pobj to NN
# . PUNCT punct makes .
# Nowhere ADV advmod was RB
# , PUNCT punct was ,
# it PRON nsubj was PRP
# was AUX ROOT was VBD
# the DET det stand DT
# stand NOUN attr was NN
# of ADP prep stand IN
# present ADJ amod appellant JJ
# appellant NOUN pobj of NN
# that SCONJ mark was IN
# the DET det land DT
# land NOUN nsubj was NN
# in ADP prep land IN
# question NOUN pobj in NN
# was AUX ccomp was VBD
# Nazul PROPN compound land NNP
# land NOUN attr was NN
# . PUNCT punct was .
# Therefore ADV advmod apply RB
# , PUNCT punct apply ,
# the DET det question DT
# question NOUN nsubj apply NN
# of ADP prep question IN
# applying VERB pcomp of VBG
# Rule-17 PROPN dobj applying NNP
# does AUX aux apply VBZ
# not PART neg apply RB
# apply VERB ROOT apply VB
# . PUNCT punct apply .
# 8 NUM ROOT 8 CD
# . PUNCT punct 8 .
# Additionally ADV advmod has RB
# , PUNCT punct has ,
# Section NOUN nsubj has NN
# 87 NUM nummod Section CD
# of ADP prep Section IN
# The DET det Act DT
# Delhi PROPN compound operative NNP
# Co PROPN dep - NNP
# - ADJ dep operative JJ
# operative ADJ amod Act JJ
# Societies PROPN compound Act NNPS
# Act PROPN pobj of NNP
# , PUNCT punct Section ,
# 2003 NUM appos Section CD
# also ADV advmod has RB
# has AUX ROOT has VBZ
# some DET det relevance DT
# relevance NOUN dobj has NN
# . PUNCT punct has .
# The DET det reads DT
# same ADJ amod reads JJ
# reads VERB ROOT reads VBZ
# as SCONJ mark follows IN
# follows VERB advcl reads VBZ
# : PUNCT punct follows :
# " PUNCT punct follows ``
# 87 NUM dobj follows CD
# . PUNCT punct reads .
# Additional ADJ ROOT Additional JJ
# around ADV advmod Additional RB
# for ADP prep Additional IN
# cessation NOUN pobj for NN
# of ADP prep cessation IN
# membership NOUN pobj of NN
# of ADP prep membership IN
# co ADJ dep - JJ
# - ADJ dep operative JJ
# operative ADJ amod society JJ
# housing NOUN compound society NN
# society NOUN pobj of NN
# - PUNCT punct Subject :
# Subject NOUN advcl cease NN
# to ADP prep Subject IN
# the DET det provision DT
# provision NOUN pobj to NN
# of ADP prep provision IN
# this DET det Act DT
# Act PROPN pobj of NNP
# , PUNCT punct cease ,
# in ADP prep cease IN
# the DET det case DT
# case NOUN pobj in NN
# of ADP prep case IN
# a DET det society DT
# co ADJ dep - JJ
# - ADJ dep operative JJ
# operative ADJ amod society JJ
# housing NOUN compound society NN
# society NOUN pobj of NN
# , PUNCT punct cease ,
# a DET det person DT
# person NOUN nsubj cease NN
# shall VERB aux cease MD
# also ADV advmod cease RB
# cease VERB ROOT cease VB
# to PART aux be TO
# be AUX xcomp cease VB
# a DET det member DT
# member NOUN attr be NN
# of ADP prep member IN
# a DET det society DT
# co- ADJ compound society JJ
# operative ADJ amod society JJ
# society NOUN pobj of NN
# - PUNCT punct society ,
# ( PUNCT punct a -LRB-
# a NOUN meta disposing NN
# ) PUNCT punct a -RRB-
# an DET det disposing DT
# disposing NOUN ROOT disposing NN
# of ADP prep disposing IN
# the DET det property DT
# property NOUN pobj of NN
# through ADP prep disposing IN
# instrument NOUN pobj through NN
# of ADP prep instrument IN
# power NOUN pobj of NN
# of ADP prep power IN
# attorney NOUN pobj of NN
# and CCONJ cc attorney CC
# agreement NOUN conj attorney NN
# for ADP prep power IN
# sale NOUN pobj for NN
# subject ADJ amod sale JJ
# to ADP prep subject IN
# the DET det interest DT
# interest NOUN pobj to NN
# of ADP prep interest IN
# the DET det mortgage DT
# mortgage NOUN pobj of NN
# if SCONJ mark is IN
# there PRON expl is EX
# is AUX advcl disposing VBZ
# any DET det loan DT
# loan NOUN attr is NN
# on ADP prep loan IN
# the DET det property DT
# property NOUN pobj on NN
# ; PUNCT punct disposing :
# or CCONJ cc disposing CC
# ( PUNCT punct b -LRB-
# b X intj disposing LS
# ) PUNCT punct b -RRB-
# if SCONJ mark he IN
# he PRON advcl b PRP
# - PUNCT punct he .
# ( PUNCT punct i -LRB-
# i NOUN ROOT i NN
# ) PUNCT punct i -RRB-
# before ADP prep i IN
# becoming VERB pcomp before VBG
# a DET det member DT
# member NOUN attr becoming NN
# of ADP prep member IN
# a DET det society DT
# co- ADJ amod society JJ
# operative ADJ amod society JJ
# housing NOUN compound society NN
# society NOUN pobj of NN
# , PUNCT punct before ,
# already ADV advmod owns RB
# owns VERB pcomp before VBZ
# , PUNCT punct before ,
# either CCONJ preconj in CC
# in ADP prep before IN
# his DET poss name PRP$
# own ADJ amod name JJ
# name NOUN pobj in NN
# or CCONJ cc in CC
# in ADP conj in IN
# the DET det name DT
# name NOUN pobj in NN
# of ADP prep name IN
# his DET poss spouse PRP$
# spouse NOUN pobj of NN
# or CCONJ cc spouse CC
# any DET conj spouse DT
# of ADP prep any IN
# his DET poss children PRP$
# dependent ADJ amod children JJ
# children NOUN pobj of NNS
# . PUNCT punct i .
# ( PUNCT punct ii -LRB-
# ii PROPN nsubj acquires NNP
# ) PUNCT punct ii -RRB-
# after ADP prep ii IN
# becoming VERB pcomp after VBG
# a DET det member DT
# member NOUN attr becoming NN
# in ADP prep member IN
# a DET det society DT
# co- ADJ amod society JJ
# operative ADJ amod society JJ
# housing NOUN compound society NN
# society NOUN pobj in NN
# , PUNCT punct acquires ,
# during ADP prep acquires IN
# the DET det currency DT
# currency NOUN pobj during NN
# of ADP prep currency IN
# such ADJ amod membership JJ
# membership NOUN pobj of NN
# , PUNCT punct acquires ,
# till SCONJ prep acquires IN
# allotment NOUN pobj till NN
# of ADP prep allotment IN
# any DET det plot DT
# plot NOUN pobj of NN
# or CCONJ cc plot CC
# flat ADJ conj plot JJ
# to ADP prep plot IN
# him PRON pobj to PRP
# , PUNCT punct acquires ,
# as SCONJ mark be IN
# the DET det case DT
# case NOUN nsubj be NN
# may VERB aux be MD
# be AUX advcl acquires VB
# , PUNCT punct acquires ,
# acquires VERB ROOT acquires VBZ
# either CCONJ preconj in CC
# in ADP prep acquires IN
# his DET poss name PRP$
# own ADJ amod name JJ
# name NOUN pobj in NN
# or CCONJ cc in CC
# in ADP conj in IN
# the DET det name DT
# name NOUN pobj in NN
# of ADP prep name IN
# his DET poss spouse PRP$
# spouse NOUN pobj of NN
# or CCONJ cc spouse CC
# any DET conj spouse DT
# of ADP prep any IN
# his DET poss children PRP$
# dependent ADJ amod children JJ
# children NOUN pobj of NNS
# , PUNCT punct children ,
# a DET det property DT
# residential ADJ amod property JJ
# property NOUN appos children NN
# exceeding VERB acl property VBG
# 66.72 NUM nummod sq CD
# sq NOUN dobj exceeding NN
# , PUNCT punct sq ,
# metres NOUN appos sq NNS
# in ADP prep metres IN
# area NOUN pobj in NN
# , PUNCT punct Provided ,
# in ADP prep Provided IN
# any DET pobj in DT
# of ADP prep any IN
# the DET det colonies DT
# approved VERB amod colonies VBN
# or CCONJ cc approved CC
# unapproved ADJ conj approved JJ
# colonies NOUN pobj of NNS
# or CCONJ cc colonies CC
# other ADJ amod localities JJ
# localities NOUN conj colonies NNS
# in ADP prep localities IN
# Delhi PROPN pobj in NNP
# either CCONJ preconj on CC
# on ADP prep in IN
# lease NOUN compound hold NN
# hold VERB compound basis VBP
# basis NOUN pobj on NN
# or CCONJ cc basis CC
# free ADJ amod hold JJ
# hold NOUN compound basis NN
# basis NOUN conj basis NN
# or CCONJ cc basis CC
# own ADJ amod power JJ
# power NOUN conj basis NN
# of ADP prep power IN
# attorney NOUN pobj of NN
# or CCONJ cc of CC
# on ADP conj of IN
# agreement NOUN pobj on NN
# for ADP prep agreement IN
# sale NOUN compound basis NN
# basis NOUN pobj for NN
# : PUNCT punct Provided :
# Provided VERB ROOT Provided VBN
# that SCONJ mark disqualified IN
# no DET det person DT
# person NOUN nsubjpass disqualified NN
# having VERB acl person VBG
# residential ADJ amod property JJ
# property NOUN dobj having NN
# under ADP prep having IN
# this DET det Section DT
# Section NOUN pobj under NN
# in ADP prep Section IN
# the DET det area DT
# village NOUN compound area NN
# abadi NOUN compound area NNS
# area NOUN pobj in NN
# in ADP prep area IN
# Delhi PROPN pobj in NNP
# shall VERB aux disqualified MD
# be AUX auxpass disqualified VB
# disqualified VERB ccomp Provided VBN
# : PUNCT punct Provided :
# Provided VERB dep Provided VBN
# further ADV advmod Provided RB
# that SCONJ mark be IN
# no DET det disqualification DT
# such ADJ amod disqualification JJ
# disqualification NOUN nsubj be NN
# shall VERB aux be MD
# be AUX ccomp Provided VB
# applicable ADJ acomp be JJ
# in ADP prep applicable IN
# the DET det case DT
# case NOUN pobj in NN
# of ADP prep case IN
# a DET det person DT
# person NOUN pobj of NN
# who PRON nsubj acquired WP
# has AUX aux acquired VBZ
# acquired VERB relcl person VBN
# property NOUN dobj acquired NN
# on ADP prep acquired IN
# power NOUN pobj on NN
# of ADP prep power IN
# attorney NOUN pobj of NN
# or CCONJ cc of CC
# through ADP conj of IN
# agreement NOUN pobj through NN
# for ADP prep agreement IN
# sale NOUN pobj for NN
# and CCONJ cc for CC
# on ADP conj for IN
# conversation NOUN pobj on NN
# of ADP prep conversation IN
# the DET det property DT
# property NOUN pobj of NN
# from ADP prep conversation IN
# leasehold NOUN pobj from NN
# to PART aux freehold TO
# freehold VERB advcl acquired VB
# on ADP prep freehold IN
# execution NOUN pobj on NN
# of ADP prep execution IN
# conveyance NOUN compound deed NN
# deed VERB pobj of VBN
# for ADP prep deed IN
# it PRON pobj for PRP
# , PUNCT punct Provided ,
# if SCONJ mark applies IN
# such ADJ amod person JJ
# person NOUN nsubj applies NN
# applies VERB advcl Provided VBZ
# for ADP prep applies IN
# the DET det membership DT
# membership NOUN pobj for NN
# of ADP prep membership IN
# the DET det society DT
# co ADJ dep - JJ
# - ADJ dep operative JJ
# operative ADJ amod society JJ
# housing NOUN compound society NN
# society NOUN pobj of NN
# concerned VERB advcl applies VBN
# : PUNCT punct Provided :
# Provided VERB advcl Provided VBN
# also ADV advmod Provided RB
# that SCONJ mark earn IN
# no DET det member DT
# member NOUN nsubj earn NN
# shall VERB aux earn MD
# earn VERB ccomp Provided VB
# disqualification NOUN dobj earn NN
# in ADP prep disqualification IN
# clause NOUN pobj in NN
# ( PUNCT punct clause -LRB-
# b NOUN appos clause NN
# ) PUNCT punct clause -RRB-
# above ADV advmod earn RB
# , PUNCT punct Provided ,
# if SCONJ mark devolves IN
# the DET det Property DT
# residential ADJ amod Property JJ
# Property PROPN nsubj devolves NNP
# devolves VERB advcl Provided VBZ
# on ADP prep devolves IN
# his DET pobj on PRP$
# by ADP prep devolves IN
# way NOUN pobj by NN
# of ADP prep way IN
# inheritance NOUN pobj of NN
# . PUNCT punct Provided .
# " PUNCT punct Provided ''
# http://JUDIS.NIC.IN ADJ compound COURT JJ
# SUPREME ADJ compound COURT JJ
# COURT PROPN ROOT COURT NNP
# OF ADP prep COURT IN
# INDIA PROPN pobj OF NNP
# Page PROPN ROOT Page NNP
# 4 NUM nummod Page CD
# of ADP prep Page IN
# 4 NUM nummod 9 CD
# 9 NUM pobj of CD
# . PUNCT punct Page .
# The DET det proviso DT
# last ADJ amod proviso JJ
# proviso NOUN nsubj makes NN
# to ADP prep proviso IN
# Section NOUN pobj to NN
# 87 NUM nummod Section CD
# makes VERB ROOT makes VBZ
# the DET det position DT
# position NOUN nsubj clear NN
# clear ADJ ccomp makes JJ
# that SCONJ mark apply IN
# it PRON nsubj apply PRP
# does AUX aux apply VBZ
# not PART neg apply RB
# apply VERB ccomp clear VB
# to ADP prep apply IN
# a DET det case DT
# case NOUN pobj to NN
# of ADP prep case IN
# inheritance NOUN pobj of NN
# . PUNCT punct makes .
# The DET det position DT
# undisputed ADJ amod position JJ
# position NOUN nsubj is NN
# is AUX ROOT is VBZ
# that SCONJ prep is IN
# the DET det property DT
# property NOUN attr is NN
# devolved VERB acl property VBN
# on ADP prep devolved IN
# the DET det no.1 DT
# respondent NOUN compound no.1 NN
# no.1 NOUN pobj on NN
# by ADP agent devolved IN
# way NOUN pobj by NN
# of ADP prep way IN
# inheritance NOUN pobj of NN
# . PUNCT punct is .
# But CCONJ cc is CC
# it PRON nsubj is PRP
# is AUX ROOT is VBZ
# not PART neg is RB
# necessary ADJ acomp is JJ
# to PART aux go TO
# go VERB xcomp is VB
# into ADP prep go IN
# the DET det question DT
# question NOUN pobj into NN
# in ADP prep question IN
# the DET det dispute DT
# present ADJ amod dispute JJ
# dispute NOUN pobj in NN
# because SCONJ mark was IN
# there PRON expl was EX
# was AUX advcl is VBD
# no DET det material DT
# material NOUN attr was NN
# placed VERB acl material VBN
# before ADP prep placed IN
# the DET det Court DT
# High PROPN compound Court NNP
# Court PROPN pobj before NNP
# to PART aux justify TO
# justify VERB acl material VB
# the DET det stand DT
# stand NOUN dobj justify NN
# that DET mark had WDT
# Rule-17 PROPN nsubj had NNP
# had AUX relcl stand VBD
# any DET det application DT
# application NOUN dobj had NN
# . PUNCT punct is .
# 10 NUM ROOT 10 CD
# . PUNCT punct 10 .
# In ADP prep suffer IN
# view NOUN pobj In NN
# of ADP prep view IN
# the DET det aforesaid DT
# aforesaid VERB pobj of VBN
# , PUNCT punct suffer ,
# the DET det Court DT
# High PROPN compound Court NNP
# Court PROPN nsubj suffer NNP
# ’s PART punct suffer POS
# view NOUN nsubj suffer NN
# does AUX aux suffer VBZ
# not PART neg suffer RB
# suffer VERB ROOT suffer VB
# from ADP prep suffer IN
# any DET det infirmity DT
# infirmity NOUN pobj from NN
# to PART aux warrant TO
# warrant VERB advcl suffer VB
# interference NOUN dobj warrant NN
# . PUNCT punct suffer .
# The DET det appeal DT
# appeal NOUN nsubj is NN
# is AUX ROOT is VBZ
# devoid ADJ acomp is JJ
# of ADP prep devoid IN
# merit NOUN pobj of NN
# and CCONJ cc is CC
# is AUX auxpass dismissed VBZ
# dismissed VERB conj is VBN
# but CCONJ cc dismissed CC
# in ADP conj dismissed IN
# the DET det circumstances DT
# circumstances NOUN pobj in NNS
# , PUNCT punct dismissed ,
# without ADP prep dismissed IN
# any DET det order DT
# order NOUN pobj without NN
# as SCONJ prep order IN
# to ADP prep as IN
# costs NOUN pobj to NNS
# . PUNCT punct is .

# %%
for ent in doc.ents:
    print(ent.text, ent.label_,ent)
# Out:
# http://JUDIS.NIC.IN SUPREME COURT OF INDIA ORG http://JUDIS.NIC.IN SUPREME COURT OF INDIA
# 1 CARDINAL 1
# 4 CARDINAL 4
# 5373 CARDINAL 5373
# 2007 DATE 2007
# Delhi Development Authority ORG Delhi Development Authority
# Arjun Lal Satija PERSON Arjun Lal Satija
# 23/11/2007 TIME 23/11/2007
# ARIJIT PASAYAT & LOKESHWAR SINGH PANTA & P. SATHASIVAM ORG ARIJIT PASAYAT & LOKESHWAR SINGH PANTA & P. SATHASIVAM
# U D G PERSON U D G
# 2007 DATE 2007
# 4024 CARDINAL 4024
# ARIJIT PASAYAT PERSON ARIJIT PASAYAT
# J. 1 PERSON J. 1
# 2 CARDINAL 2
# the Delhi High Court ORG the Delhi High Court
# no.1 3 DATE no.1 3
# The Mianwali District Cooperative House Building Society Ltd. ORG The Mianwali District Cooperative House Building Society Ltd.
# Flat No ORG Flat No
# New Qutab Road FAC New Qutab Road
# Delhi GPE Delhi
# Society ORG Society
# Society ORG Society
# No.1 CARDINAL No.1
# 22.11.1974 WORK_OF_ART 22.11.1974
# No.1 CARDINAL No.1
# The Managing Committee ORG The Managing Committee
# Shri K.K. Satija ORG Shri K.K. Satija
# No.1 CARDINAL No.1
# No.1 CARDINAL No.1
# the Registrar of Cooperative Societies ORG the Registrar of Cooperative Societies
# ’the Registrar’ WORK_OF_ART ’the Registrar’
# 16.05.1994 ORG 16.05.1994
# No.1 CARDINAL No.1
# Society ORG Society
# Saraswati Vihar PERSON Saraswati Vihar
# Delhi GPE Delhi
# 13.10.1994 ORG 13.10.1994
# under Section 80 LAW under Section 80
# the Delhi Cooperative Societies Act ORG the Delhi Cooperative Societies Act
# 1972 DATE 1972
# the Delhi High Court ORG the Delhi High Court
# No.1 CARDINAL No.1
# The Delhi High Court ORG The Delhi High Court
# No.1 CARDINAL No.1
# the High Court ORG the High Court
# Two and four weeks DATE Two and four weeks
# the http://JUDIS.NIC.IN SUPREME COURT OF INDIA ORG the http://JUDIS.NIC.IN SUPREME COURT OF INDIA
# 2 CARDINAL 2
# 4 CARDINAL 4
# the Registrar, Cooperative Societies-respondent No.2 ORG the Registrar, Cooperative Societies-respondent No.2
# 300 CARDINAL 300
# 19.02.2004 ORG 19.02.2004
# No.1 CARDINAL No.1
# No.1 CARDINAL No.1
# No.1 CARDINAL No.1
# The Division Bench ORG The Division Bench
# No.1 CARDINAL No.1
# Rule-17 GPE Rule-17
# the Delhi Development Authority ORG the Delhi Development Authority
# Rules GPE Rules
# 1981 DATE 1981
# the ’Rules’ LAW the ’Rules’
# The High Court ORG The High Court
# Rules PERSON Rules
# No.1 CARDINAL No.1
# 17 CARDINAL 17
# the High Court ORG the High Court
# Rule 17 LAW Rule 17
# Section 87 of the Act LAW Section 87 of the Act
# 6 CARDINAL 6
# Rule-17 GPE Rule-17
# 17 CARDINAL 17
# Nazul LOC Nazul
# 6 CARDINAL 6
# the Union Territory of Delhi ORG the Union Territory of Delhi
# Nazul GPE Nazul
# less than 67 square metres QUANTITY less than 67 square metres
# less than 67 square metres QUANTITY less than 67 square metres
# less than 67 square metres QUANTITY less than 67 square metres
# http://JUDIS.NIC.IN SUPREME COURT OF INDIA ORG http://JUDIS.NIC.IN SUPREME COURT OF INDIA
# 3 CARDINAL 3
# 4 CARDINAL 4
# Nazul LOC Nazul
# 7 CARDINAL 7
# Rule PERSON Rule
# Nazul ORG Nazul
# Nazul PRODUCT Nazul
# Rule-17 PERSON Rule-17
# Section 87 LAW Section 87
# The Delhi Co-operative Societies Act WORK_OF_ART The Delhi Co-operative Societies Act
# 2003 DATE 2003
# 87 CARDINAL 87
# 66.72 sq QUANTITY 66.72 sq
# Delhi GPE Delhi
# Delhi GPE Delhi
# http://JUDIS.NIC.IN SUPREME COURT ORG http://JUDIS.NIC.IN SUPREME COURT
# 4 CARDINAL 4
# Section 87 LAW Section 87
# the High Court ORG the High Court
# Rule-17 PERSON Rule-17
# 10 CARDINAL 10
# the High Court ORG the High Court

# %% [markdown]
# ### Main

# %%
appellant_regex = [
    r"\B([\.\w\s&]*)\s+([…\s\.]*APPELLANT)",
    r"petitioner:\v*([\W\S]*)respondent:",
]

# %%
respondent_regex = [
    r"(versus|v\.s\.|vs\.|v\.s|v\/s)([\/\.\w\s&\\]*)\s{2,3}([…\s\.]*respondent)",
    r"respondent:\v*(.*)date of judgment:",
]

# %%
date_of_judgement_regex = [r"date of judgment:\v*(.*)bench:"]

# %%
bench_regex = [r"bench:\v*(.*)judgment"]

# %%
not_found_files = []

# %%
df.head()
# Out:
#                               file-name  \
# 0  35177_2015_Judgement_08-Dec-2017.txt
# 1                             40216.txt
# 2                             30829.txt
# 3                             33421.txt
# 4                             43039.txt
#
#                                                 text  tag
# 0                                                ...  NaN
# 1                                                ...  NaN
# 2  http://JUDIS.NIC.IN                SUPREME COU...  NaN
# 3                                                ...  NaN
# 4                                                ...  NaN

# %%
def tags(row):
    text = row["text"]
    appellant = re.findall(
        appellant_regex[1], text, re.MULTILINE | re.IGNORECASE
    )
    if len(appellant) > 0:
        print(appellant[0], row["file-name"])
        respondent = re.findall(
            respondent_regex[1], text, re.MULTILINE | re.IGNORECASE
        )
        date = re.findall(
            date_of_judgement_regex[0], text, re.MULTILINE | re.IGNORECASE
        )
        bench = re.findall(bench_regex[0], text, re.MULTILINE | re.IGNORECASE)
        print(appellant,respondent,date,bench)
    else:
        appellant = re.findall(
            appellant_regex[0], text, re.MULTILINE | re.IGNORECASE
        )
        if len(appellant) > 0:
            print(appellant[0][0], row["file-name"])
            respondent = re.findall(
                respondent_regex[0], text, re.MULTILINE | re.IGNORECASE
            )
        else:
            not_found_files.append(row["file-name"])

# %%
t = df.iloc[:10, :]

# %%
a = t.apply(tags, axis=1)
# Out:
#                          VIJAY KUMAR AND ANOTHER                    35177_2015_Judgement_08-Dec-2017.txt
#
#
# Sandeep Kumar Chourasia                                  40216.txt
#
# M/S TEXMACO LTD. CEMENT DIVISION
#
#  30829.txt
# ['\nM/S TEXMACO LTD. CEMENT DIVISION\n\n'] [] [] []
#
#
#
# Mahesh Yadav & Anr.                                    33421.txt
# TAR INDUSTRIES                                      43039.txt
#
#
#           SHAMSHER SINGH & ANR.                                       2251_2010_11_1501_15425_Judgement_29-Jul-2019.txt
#
#
# MANEESH BAWA AND ORS.                                           44440.txt
#  B.C.C.L.         .....         36775.txt
#  SPORTS & LEISURE APPAREL LTD.          43794.txt
#
#
#
# UNION OF INDIA & ORS.                       40617.txt

# %%
not_found_files
# Out:
# []

# %%
df[df.iloc[:, 1].str.contains("PETITIONER")].shape
# Out:
# (2442, 3)

# %%
df.iloc[5, 0]
# Out:
# '2251_2010_11_1501_15425_Judgement_29-Jul-2019.txt'

# %%
df.iloc[295, 1]
# Out:
# "                                                               1\n\n                                                                                                 REPORTABLE\n\n                                           IN THE SUPREME COURT OF INDIA\n                                            CIVIL APPELLATE JURISDICTION\n\n                                        CIVIL APPEAL NO. 1820 OF 2018\n                              [@ SPECIAL LEAVE PETITION (C) NOS. 9820 OF 2016]\n\n                         R K ARORA GENERAL MANAGER & ANR.                                 Appellant(s)\n\n                                                              VERSUS\n\n                         M/S ACE ENTERPRISES                                               Respondent(s)\n\n                                                   J U D G M E N T\n\n\n                         KURIAN, J.\n\n                         1.   Leave granted.\n\n                         2.   On    22.06.2011,        the     Court        of    Small     Causes,\n\n                         Srinagar,     passed     an    order        of    injunction       in   the\n\n                         following terms :-\n\n                               “The    application        in       hand    will     not    be\n                               allowed, there are chances that the suit\n                               of the applicant will become infructuous.\n                               So     in    the   interests          of     justice       the\n                               application in hand is allowed and the\n                               proceedings before the arbitration with\n                               regard        to    matter          titled         M/s     ACE\n                               Enterprises Vs. Union of India and ors is\n                               stayed till the objections from the other\n                               side    is    filed.          Put    up     this    file    on\n                               26-07-11.”\n\n\n\nSignature Not Verified   3.   Alleging      violation        of      the     above      order,   an\nDigitally signed by\nJAYANT KUMAR ARORA\nDate: 2018.02.13\n17:13:04 IST\nReason:\n                         application       was    filed        for        initiating       contempt\n\n                         proceedings.       The prayer reads as follows :-\n\x0c                                          2\n\n        “It is therefore prayed that the contempt\n        proceedings          may    please         be    intiated         and\n        the contemnors be punished according to\n        law and the order of revival passed by\n        the Arbitrator may please be stayed.”\n\n\n\n4.    The Court of Small Causes treated the application\n\nfiled     by     the     respondent           as        an     application           for\n\ncontempt       without       mentioning        any       provision.             It   is\n\nalso significant to note that even the applicant had\n\nnot mentioned any provision for initiating contempt.\n\nThe     Court    passed        an    order           dated       06.11.2013          by\n\nentering a finding that there is no contempt and that\n\nthere is no violation of the order dated 22.06.2011.\n\nThe operative portion of the order, to the extent\n\nrelevant, reads as follows :-\n\n         “The     proceedings            of        the        arbitration\n         continued by the Arbitrator, is based on\n         the understanding of the Arbitrator and\n         the learned counsel for the defendants as\n         to the correct import of the order dated\n         22-06-2011.               The        said       understanding\n         arrived at, though is borne out from the\n         facts and circumstances pertaining to the\n         controversy,          cannot          be       construed          as\n         willful       and    deliberate            attempt          on   the\n   ...
